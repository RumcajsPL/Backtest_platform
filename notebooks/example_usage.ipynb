# %%
# notebooks/example_usage.ipynb or example_usage.py
"""
Example usage of the updated backtesting platform
"""
import sys
from pathlib import Path

# Add src to path
src_path = Path(__file__).parent.parent / "src"
sys.path.append(str(src_path))

from src.indicators.wbws_trigger import WBWSTrigger
from src.config import paths

# Initialize the indicator
wbws = WBWSTrigger()

# Load and process data
try:
    df = wbws.load_and_process()
    print(f"Data shape: {df.shape}")
    print(f"Data columns: {df.columns.tolist()}")
except Exception as e:
    print(f"Error: {e}")
    print(f"Please ensure your data is in: {paths.RAW_DATA_DIR}")
